# %%
import statsmodels.tsa.seasonal
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
os.chdir('c:\\Users\\Viktor\\Documents\\Gitportfolio\\Projeto C19 Prever')
os.getcwd()

# %%
data = pd.read_csv(r'C:data\clean\solicitacao de servico diaria.csv')

data.set_index('data', inplace=True)
resultado = statsmodels.tsa.seasonal.seasonal_decompose(data['solicitacoes_totais'], model='additive', period=182)

# %%
pd.DataFrame(data)

# %%
resultado.plot()
plt.show()
